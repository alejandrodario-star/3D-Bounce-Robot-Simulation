# %% [markdown]
# # 3D Bounce Robot Simulation (Binder/Jupyter)
#
# This notebook runs the underwater robot simulation in 3D and shows an inline animation.
#
# **How to use:**
# - In Binder, wait for the environment to build.
# - Run the cells from top to bottom.

# %%
# If your repo has robot_simulation.py in the same directory as this notebook:
from robot_simulation import visualize_3d

# If you want a text-only preview of impacts instead of animation:
# from robot_simulation import simulate_print
# simulate_print(robot_speed=1.0, steps=8)

# %%
# Display the 3D animation inline
# Note: In Jupyter, matplotlib's interactive 3D window is rendered inline.
# If you prefer a non-interactive HTML5 animation, additional setup is required.
# This will show a live animation in most Binder/Jupyter setups.
visualize_3d(num_impacts=250, speed=1.0, theta0=0.7, phi0=0.28, rule="B", clockwise_sign=+1, trail_len=220)
